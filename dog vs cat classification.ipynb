# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator                                                  

train_datagen = ImageDataGenerator(rescale = 1./255, shear_range =0.2, zoom_range =0.2, horizontal_flip = True)

training_set =train_datagen.flow_from_directory(r'D:\downloads\CNN', target_size = (64,64), batch_size = 32, class_mode = 'binary')

test_datagen = ImageDataGenerator(rescale = 1./255)
test_set =test_datagen.flow_from_directory(r'D:\downloads\CNN', target_size = (64,64), batch_size =32, class_mode = 'binary')

cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))          # convolutional işlemi
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))                                                  # max pooling işlemi
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))                                # ikinci convolutional katmanı 
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))                                                  # ikinci max pooling katmanı 
cnn.add(tf.keras.layers.Flatten())                                                                         # flatten işlemi yaparak verileri düzleştirdim.
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))                                               # çıkış katmanı sigmoid 0 ve 1 ler olarak çıkıyor. output 1 ise köpek, 0 ise kedi dir.

cnn.compile(optimizer = 'adam', loss ='binary_crossentropy',metrics = ['accuracy'])
cnn.fit(x =training_set,validation_data = test_set,epochs=10)                                             



import numpy as np
import keras.utils as image

test_image = image.load_img(r'D:\downloads\Test 1.jpg',target_size =(64,64))
test_image = image.img_to_array(test_image)
test_image =np.expand_dims(test_image,axis=0)

prediction = cnn.predict(test_image)
training_set.class_indices

if prediction[0][0] == 1:
    print("DOG")
else:
    print("CAT")
# Out:
# Found 37 images belonging to 2 classes.
# Found 37 images belonging to 2 classes.
# Epoch 1/10
# 2/2 [==============================] - 2s 586ms/step - loss: 0.6755 - accuracy: 0.5676 - val_loss: 0.6060 - val_accuracy: 0.6216
# Epoch 2/10
# 2/2 [==============================] - 0s 169ms/step - loss: 0.6186 - accuracy: 0.6216 - val_loss: 0.7685 - val_accuracy: 0.5135
# Epoch 3/10
# 2/2 [==============================] - 0s 325ms/step - loss: 0.8546 - accuracy: 0.5135 - val_loss: 0.5767 - val_accuracy: 0.5676
# Epoch 4/10
# 2/2 [==============================] - 0s 168ms/step - loss: 0.6149 - accuracy: 0.5405 - val_loss: 0.6939 - val_accuracy: 0.5135
# Epoch 5/10
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6920 - accuracy: 0.5135 - val_loss: 0.5297 - val_accuracy: 0.8378
# Epoch 6/10
# 2/2 [==============================] - 0s 310ms/step - loss: 0.6352 - accuracy: 0.6216 - val_loss: 0.6985 - val_accuracy: 0.5135
# Epoch 7/10
# 2/2 [==============================] - 0s 156ms/step - loss: 0.7083 - accuracy: 0.5405 - val_loss: 0.6865 - val_accuracy: 0.5135
# Epoch 8/10
# 2/2 [==============================] - 0s 316ms/step - loss: 0.6427 - accuracy: 0.5676 - val_loss: 0.5695 - val_accuracy: 0.5946
# Epoch 9/10
# 2/2 [==============================] - 0s 171ms/step - loss: 0.5972 - accuracy: 0.5946 - val_loss: 0.5441 - val_accuracy: 0.9189
# Epoch 10/10
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5709 - accuracy: 0.8378 - val_loss: 0.5316 - val_accuracy: 0.8919
# 1/1 [==============================] - 0s 125ms/step
# DOG

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator                                                  

train_datagen = ImageDataGenerator(rescale = 1./255, shear_range =0.2, zoom_range =0.2, horizontal_flip = True)

training_set =train_datagen.flow_from_directory(r'D:\downloads\CNN', target_size = (64,64), batch_size = 32, class_mode = 'binary')

test_datagen = ImageDataGenerator(rescale = 1./255)
test_set =test_datagen.flow_from_directory(r'D:\downloads\CNN', target_size = (64,64), batch_size =32, class_mode = 'binary')

cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))          # convolutional işlemi
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))                                                  # max pooling işlemi
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))                                # ikinci convolutional katmanı 
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))                                                  # ikinci max pooling katmanı 
cnn.add(tf.keras.layers.Flatten())                                                                         # flatten işlemi yaparak verileri düzleştirdim.
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))                                               # çıkış katmanı sigmoid 0 ve 1 ler olarak çıkıyor. output 1 ise köpek, 0 ise kedi dir.

cnn.compile(optimizer = 'adam', loss ='binary_crossentropy',metrics = ['accuracy'])
cnn.fit(x =training_set,validation_data = test_set,epochs=10)                                             



import numpy as np
import keras.utils as image

test_image = image.load_img(r'D:\downloads\Test 2.jpg',target_size =(64,64))
test_image = image.img_to_array(test_image)
test_image =np.expand_dims(test_image,axis=0)

prediction = cnn.predict(test_image)
training_set.class_indices

if prediction[0][0] == 1:
    print("DOG")
else:
    print("CAT")
# Out:
# Found 37 images belonging to 2 classes.
# Found 37 images belonging to 2 classes.
# Epoch 1/10
# 2/2 [==============================] - 2s 560ms/step - loss: 1.2795 - accuracy: 0.4324 - val_loss: 0.9549 - val_accuracy: 0.5135
# Epoch 2/10
# 2/2 [==============================] - 0s 166ms/step - loss: 0.8785 - accuracy: 0.5135 - val_loss: 0.6863 - val_accuracy: 0.6486
# Epoch 3/10
# 2/2 [==============================] - 0s 167ms/step - loss: 0.6926 - accuracy: 0.6216 - val_loss: 0.6982 - val_accuracy: 0.4865
# Epoch 4/10
# 2/2 [==============================] - 0s 147ms/step - loss: 0.6989 - accuracy: 0.4865 - val_loss: 0.6878 - val_accuracy: 0.5135
# Epoch 5/10
# 2/2 [==============================] - 0s 170ms/step - loss: 0.6855 - accuracy: 0.5405 - val_loss: 0.6814 - val_accuracy: 0.5135
# Epoch 6/10
# 2/2 [==============================] - 0s 167ms/step - loss: 0.6757 - accuracy: 0.5135 - val_loss: 0.6899 - val_accuracy: 0.5135
# Epoch 7/10
# 2/2 [==============================] - 0s 179ms/step - loss: 0.6897 - accuracy: 0.5135 - val_loss: 0.7033 - val_accuracy: 0.5135
# Epoch 8/10
# 2/2 [==============================] - 0s 163ms/step - loss: 0.6990 - accuracy: 0.5135 - val_loss: 0.6914 - val_accuracy: 0.5135
# Epoch 9/10
# 2/2 [==============================] - 0s 333ms/step - loss: 0.6764 - accuracy: 0.5135 - val_loss: 0.6701 - val_accuracy: 0.5135
# Epoch 10/10
# 2/2 [==============================] - 0s 312ms/step - loss: 0.6615 - accuracy: 0.5135 - val_loss: 0.6506 - val_accuracy: 0.5135
# 1/1 [==============================] - 0s 94ms/step
# CAT

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import keras.utils as image

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

training_set = train_datagen.flow_from_directory(r'D:\downloads\CNN', target_size=(64, 64), batch_size=32, class_mode='binary')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(r'D:\downloads\CNN', target_size=(64, 64), batch_size=32, class_mode='binary')

cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn.fit(x=training_set, validation_data=test_set, epochs=10)

test_image_path = r'D:\downloads\Test 3.jpg'
test_image = image.load_img(test_image_path, target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

prediction = cnn.predict(test_image)
training_set.class_indices

if prediction[0][0] == 1:
    print("DOG")
elif prediction[0][0] == 0:
    print("CAT")
else:
    print("OTHER ANIMAL")
# Out:
# Found 37 images belonging to 2 classes.
# Found 37 images belonging to 2 classes.
# Epoch 1/10
# 2/2 [==============================] - 2s 416ms/step - loss: 0.7795 - accuracy: 0.4324 - val_loss: 0.6714 - val_accuracy: 0.5135
# Epoch 2/10
# 2/2 [==============================] - 0s 330ms/step - loss: 0.7438 - accuracy: 0.5135 - val_loss: 0.7417 - val_accuracy: 0.5135
# Epoch 3/10
# 2/2 [==============================] - 0s 316ms/step - loss: 0.6968 - accuracy: 0.5135 - val_loss: 0.6691 - val_accuracy: 0.5135
# Epoch 4/10
# 2/2 [==============================] - 0s 321ms/step - loss: 0.6627 - accuracy: 0.5135 - val_loss: 0.6572 - val_accuracy: 0.5135
# Epoch 5/10
# 2/2 [==============================] - 0s 311ms/step - loss: 0.6617 - accuracy: 0.5135 - val_loss: 0.6504 - val_accuracy: 0.5135
# Epoch 6/10
# 2/2 [==============================] - 0s 314ms/step - loss: 0.6482 - accuracy: 0.5135 - val_loss: 0.6314 - val_accuracy: 0.5135
# Epoch 7/10
# 2/2 [==============================] - 0s 161ms/step - loss: 0.6385 - accuracy: 0.5405 - val_loss: 0.6123 - val_accuracy: 0.5135
# Epoch 8/10
# 2/2 [==============================] - 0s 163ms/step - loss: 0.6203 - accuracy: 0.5135 - val_loss: 0.5898 - val_accuracy: 0.5405
# Epoch 9/10
# 2/2 [==============================] - 0s 291ms/step - loss: 0.5914 - accuracy: 0.5676 - val_loss: 0.5760 - val_accuracy: 0.5676
# Epoch 10/10
# 2/2 [==============================] - 0s 309ms/step - loss: 0.5636 - accuracy: 0.8108 - val_loss: 0.5431 - val_accuracy: 0.7568
# 1/1 [==============================] - 0s 81ms/step
# OTHER ANIMAL
